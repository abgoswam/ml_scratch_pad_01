# %%
import torch

# %%
t = torch.tensor(
    [[1., 2.],
     [3., 4.]]
)

m = torch.tensor(
    [[1, 1],
     [0, 0]]
)

# %%
print(t.dtype)
print(m.dtype)
# Out:
# torch.float32
# torch.int64

# %%
torch.gather(input=t, dim=-1, index=m)
# Out:
# tensor([[2., 2.],
#         [3., 3.]])
