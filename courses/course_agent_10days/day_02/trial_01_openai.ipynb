# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()  # Reads from .env file
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# In the quiet moonlit meadow, a gentle unicorn sang a lullaby of stars and tucked a peaceful dream into every sleeping heart.

# %%
response = client.chat.completions.create(
    model="gpt-4",
    messages=[{"role": "user", "content": "Write a one-sentence bedtime story about a unicorn."}]
)
print(response.choices[0].message.content)
# Out:
# In a world where dreams come true, a young unicorn embarks on a journey under the starlit sky, spreading sparkles of love and hope, painting dreams with each gallop, until it finally rests under the glow of the moon, promising to return the next night for another magical adventure.
